# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generating Sample data

# %%
data = {
    'Age' : np.random.randint(20,80,100),
    'BloodPressure' : np.random.randint(60,80,100),
    'Cholestrol' : np.random.randint(150,300,100),
    'BMI' : np.random.uniform(18.5,35,100),
    'Glucose': np.random.randint(70, 200, 100)

}

# %% [markdown]
# ###  Convert to Pandas DataFrame

# %%
df = pd.DataFrame(data)

# %%
##data set information
(df.head())
# Out:
#    Age  BloodPressure  Cholestrol        BMI  Glucose
# 0   44             69         275  34.810894      194
# 1   29             72         202  29.244082      170
# 2   49             69         190  31.767974      172
# 3   36             79         257  18.722785      137
# 4   66             62         291  20.259562      129

# %%
# Basic statistics
print(df.describe())
